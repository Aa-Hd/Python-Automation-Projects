# %%
import pandas as pd

# %%
df = pd.read_csv("matches_csv.csv")

# %% [markdown]
# 1.	How can you filter the dataset to only show matches from a specific season?

# %%
season = df[df["season"] == 2015]
season.head(80)
season.shape
# Out:
# (59, 18)

# %%
#season.to_excel("filtered_matches.xlsx", index=False)

# %% [markdown]
# 2.	Can you demonstrate how to filter the dataset to display matches held in a particular city?

# %%
city=df[df['city']=='Chennai']
city
# Out:
#       id  season     city        date                        team1  \
# 66    67    2008  Chennai  2008-04-23          Chennai Super Kings
# 70    71    2008  Chennai  2008-04-26        Kolkata Knight Riders
# 78    79    2008  Chennai  2008-05-02          Chennai Super Kings
# 84    85    2008  Chennai  2008-05-06          Chennai Super Kings
# 90    91    2008  Chennai  2008-05-10          Chennai Super Kings
# 106  107    2008  Chennai  2008-05-21  Royal Challengers Bangalore
# 109  110    2008  Chennai  2008-05-24             Rajasthan Royals
# 178  179    2010  Chennai  2010-03-14              Deccan Chargers
# 189  190    2010  Chennai  2010-03-21              Kings XI Punjab
# 201  202    2010  Chennai  2010-03-31  Royal Challengers Bangalore
# 205  206    2010  Chennai  2010-04-03          Chennai Super Kings
# 210  211    2010  Chennai  2010-04-06          Chennai Super Kings
# 221  222    2010  Chennai  2010-04-13        Kolkata Knight Riders
# ...

# %% [markdown]
# 3.	How would you extract the information for matches where the toss winner chose to bat?

# %%
toss=df[df['toss_decision']=='bat']
toss
# Out:
#       id  season           city        date                        team1  \
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 14    15    2017          Delhi  2017-04-15             Delhi Daredevils
# 17    18    2017          Delhi  2017-04-17             Delhi Daredevils
# 20    21    2017      Hyderabad  2017-04-19          Sunrisers Hyderabad
# ..   ...     ...            ...         ...                          ...
# 618  619    2016  Visakhapatnam  2016-05-13               Mumbai Indians
# 620  621    2016        Kolkata  2016-05-14      Rising Pune Supergiants
# 621  622    2016     Chandigarh  2016-05-15              Kings XI Punjab
# 628  629    2016  Visakhapatnam  2016-05-21              Kings XI Punjab
# 635  636    2016      Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# 4.	Show the steps to filter the dataset to only display matches where the result was "tie."

# %%
result=df[df['result']=='tie']
result
# Out:
#       id  season       city        date                        team1  \
# 33    34    2017     Rajkot  2017-04-29                Gujarat Lions
# 125  126    2009  Cape Town  2009-04-23             Rajasthan Royals
# 189  190    2010    Chennai  2010-03-21              Kings XI Punjab
# 387  388    2013  Hyderabad  2013-04-07  Royal Challengers Bangalore
# 400  401    2013  Bangalore  2013-04-16             Delhi Daredevils
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 535  536    2015  Ahmedabad  2015-04-21             Rajasthan Royals
#
#                            team2                  toss_winner toss_decision  \
# 33                Mumbai Indians                Gujarat Lions           bat
# 125        Kolkata Knight Riders        Kolkata Knight Riders         field
# 189          Chennai Super Kings          Chennai Super Kings         field
# 387          Sunrisers Hyderabad  Royal Challengers Bangalore           bat
# ...

# %% [markdown]
# 5.  How can you extract matches where the margin of victory was by runs and it was more than 50 runs?

# %%
victory_by_runs=df[df['win_by_runs']>=50]
victory_by_runs
# Out:
#       id  season            city        date                        team1  \
# 8      9    2017            Pune  2017-04-11             Delhi Daredevils
# 14    15    2017           Delhi  2017-04-15             Delhi Daredevils
# 26    27    2017         Kolkata  2017-04-23        Kolkata Knight Riders
# 32    33    2017            Pune  2017-04-29       Rising Pune Supergiant
# 43    44    2017           Delhi  2017-05-06               Mumbai Indians
# 59    60    2008       Bangalore  2008-04-18        Kolkata Knight Riders
# 68    69    2008      Chandigarh  2008-04-25              Kings XI Punjab
# 100  101    2008          Jaipur  2008-05-17             Rajasthan Royals
# 114  115    2008          Mumbai  2008-05-30             Rajasthan Royals
# 118  119    2009       Cape Town  2009-04-18  Royal Challengers Bangalore
# 121  122    2009  Port Elizabeth  2009-04-20          Chennai Super Kings
# 131  132    2009  Port Elizabeth  2009-04-27               Mumbai Indians
# ...

# %% [markdown]
# 6.	Demonstrate how to filter the dataset to show matches where the DL method was applied.

# %%
dl_method=df[df['dl_applied']==1]
dl_method
# Out:
#       id  season           city        date                        team1  \
# 56    57    2017      Bangalore  2017-05-17          Sunrisers Hyderabad
# 99   100    2008          Delhi  2008-05-17             Delhi Daredevils
# 102  103    2008        Kolkata  2008-05-18        Kolkata Knight Riders
# 119  120    2009      Cape Town  2009-04-19              Kings XI Punjab
# 122  123    2009         Durban  2009-04-21              Kings XI Punjab
# 148  149    2009      Centurion  2009-05-07          Chennai Super Kings
# 251  252    2011          Kochi  2011-04-18          Chennai Super Kings
# 280  281    2011        Kolkata  2011-05-07          Chennai Super Kings
# 290  291    2011      Bangalore  2011-05-14        Kolkata Knight Riders
# 488  489    2014          Delhi  2014-05-10             Delhi Daredevils
# 536  537    2015  Visakhapatnam  2015-04-22          Sunrisers Hyderabad
# 567  568    2015      Hyderabad  2015-05-15          Sunrisers Hyderabad
# ...

# %% [markdown]
# 7.	How would you filter the dataset to display matches where a specific team won?

# %%
winner=df[(df['winner']=='Kolkata Knight Riders')]
#winner.drop(index, inplace=True)
winner
# Out:
#       id  season       city        date                        team1  \
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 10    11    2017    Kolkata  2017-04-13              Kings XI Punjab
# 13    14    2017    Kolkata  2017-04-15        Kolkata Knight Riders
# 17    18    2017      Delhi  2017-04-17             Delhi Daredevils
# 26    27    2017    Kolkata  2017-04-23        Kolkata Knight Riders
# ..   ...     ...        ...         ...                          ...
# 595  596    2016       Pune  2016-04-24      Rising Pune Supergiants
# 605  606    2016  Bangalore  2016-05-02  Royal Challengers Bangalore
# 607  608    2016    Kolkata  2016-05-04        Kolkata Knight Riders
# 620  621    2016    Kolkata  2016-05-14      Rising Pune Supergiants
# 630  631    2016    Kolkata  2016-05-22        Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# 8.	Show the steps to filter the dataset to only display matches where a certain team won by a margin of more than 30 runs.

# %%
winner_with_margin=df[(df['winner']=='Rising Pune Supergiants') & (df['win_by_runs'] >= 30) ]
winner_with_margin
# Out:
#       id  season       city        date                team1  \
# 597  598    2016  Hyderabad  2016-04-26  Sunrisers Hyderabad
#
#                        team2              toss_winner toss_decision  result  \
# 597  Rising Pune Supergiants  Rising Pune Supergiants         field  normal
#
#      dl_applied                   winner  win_by_runs  win_by_wickets  \
# 597           1  Rising Pune Supergiants           34               0
#
#     player_of_match                                      venue      umpire1  \
# 597        AB Dinda  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#        umpire2  umpire3
# 597  CK Nandan      NaN

# %% [markdown]
# 9.	How can you extract matches where the 'player_of_match' was from a particular team?

# %%
player_of_match=df[(df['winner']=='Sunrisers Hyderabad') & (df['player_of_match']=='Rashid Khan'),]
player_of_match
# Out:
#     id  season        city        date                team1  \
# 5    6    2017   Hyderabad  2017-04-09        Gujarat Lions
# 31  32    2017  Chandigarh  2017-04-28  Sunrisers Hyderabad
#
#                   team2          toss_winner toss_decision  result  \
# 5   Sunrisers Hyderabad  Sunrisers Hyderabad         field  normal
# 31      Kings XI Punjab      Kings XI Punjab         field  normal
#
#     dl_applied               winner  win_by_runs  win_by_wickets  \
# 5            0  Sunrisers Hyderabad            0               9
# 31           0  Sunrisers Hyderabad           26               0
#
#    player_of_match                                              venue  \
# 5      Rashid Khan          Rajiv Gandhi International Stadium, Uppal
# 31     Rashid Khan  Punjab Cricket Association IS Bindra Stadium, ...
#
#         umpire1    umpire2  umpire3
# 5    A Deshmukh   NJ Llong      NaN
# 31  Nitin Menon  CK Nandan      NaN

# %% [markdown]
# 10.	Demonstrate how to filter the dataset to show matches where a specific umpire1 was officiating.

# %%
specific_umpire1=df[df['umpire1']=='AK Chaudhary']
specific_umpire1
# Out:
#       id  season           city        date                        team1  \
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 25    26    2017         Rajkot  2017-04-23              Kings XI Punjab
# 29    30    2017      Bangalore  2017-04-27  Royal Challengers Bangalore
# 33    34    2017         Rajkot  2017-04-29                Gujarat Lions
# 36    37    2017         Mumbai  2017-05-01  Royal Challengers Bangalore
# 51    52    2017         Kanpur  2017-05-13                Gujarat Lions
# 56    57    2017      Bangalore  2017-05-17          Sunrisers Hyderabad
# 309  310    2012         Mumbai  2012-04-06                Pune Warriors
# 315  316    2012  Visakhapatnam  2012-04-09              Deccan Chargers
# 345  346    2012         Mumbai  2012-04-29              Deccan Chargers
# 387  388    2013      Hyderabad  2013-04-07  Royal Challengers Bangalore
# ...

# %% [markdown]
# 1.	Fetch a Single Column: How would you fetch the 'team1' column from the DataFrame?

# %%
team=df['team1']
team
# Out:
# 0              Sunrisers Hyderabad
# 1                   Mumbai Indians
# 2                    Gujarat Lions
# 3           Rising Pune Supergiant
# 4      Royal Challengers Bangalore
#                   ...
# 631               Delhi Daredevils
# 632                  Gujarat Lions
# 633            Sunrisers Hyderabad
# 634                  Gujarat Lions
# 635            Sunrisers Hyderabad
# Name: team1, Length: 636, dtype: str

# %% [markdown]
# 2.	Fetch Multiple Columns: Can you fetch the 'team1', 'team2', and 'winner' columns together from the DataFrame?

# %%
multiple_columns=df[['team1','team2','winner']]
multiple_columns
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %% [markdown]
# 3.  Fetch a Single Row: How would you fetch the 10th row of the DataFrame?

# %%
row_specific=df.loc[10]
row_specific
# Out:
# id                                    11
# season                              2017
# city                             Kolkata
# date                          2017-04-13
# team1                    Kings XI Punjab
# team2              Kolkata Knight Riders
# toss_winner        Kolkata Knight Riders
# toss_decision                      field
# result                            normal
# dl_applied                             0
# winner             Kolkata Knight Riders
# win_by_runs                            0
# win_by_wickets                         8
# player_of_match                SP Narine
# venue                       Eden Gardens
# umpire1                       A Deshmukh
# umpire2                         NJ Llong
# umpire3                              NaN
# Name: 10, dtype: object

# %% [markdown]
# 4.	Fetch Multiple Rows: Can you fetch rows 20 to 30 from the DataFrame?

# %%
multiple_rows=df.loc[20:30]
multiple_rows
# Out:
#     id  season       city        date                        team1  \
# 20  21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 21  22    2017     Indore  2017-04-20              Kings XI Punjab
# 22  23    2017    Kolkata  2017-04-21        Kolkata Knight Riders
# 23  24    2017     Mumbai  2017-04-22               Mumbai Indians
# 24  25    2017       Pune  2017-04-22          Sunrisers Hyderabad
# 25  26    2017     Rajkot  2017-04-23              Kings XI Punjab
# 26  27    2017    Kolkata  2017-04-23        Kolkata Knight Riders
# 27  28    2017     Mumbai  2017-04-24       Rising Pune Supergiant
# 28  29    2017       Pune  2017-04-26       Rising Pune Supergiant
# 29  30    2017  Bangalore  2017-04-27  Royal Challengers Bangalore
# 30  31    2017    Kolkata  2017-04-28             Delhi Daredevils
#
#                           team2                  toss_winner toss_decision  \
# 20             Delhi Daredevils          Sunrisers Hyderabad           bat
# ...

# %% [markdown]
# 5.	Fetch Specific Rows and Columns: Fetch the 'city' and 'winner' columns for rows 50 to 60 from the DataFrame.

# %%
specific_rows_columns=df.loc[50:60,['city','winner']]
specific_rows_columns
# Out:
#           city                       winner
# 50       Delhi             Delhi Daredevils
# 51      Kanpur          Sunrisers Hyderabad
# 52     Kolkata               Mumbai Indians
# 53        Pune       Rising Pune Supergiant
# 54       Delhi  Royal Challengers Bangalore
# 55      Mumbai       Rising Pune Supergiant
# 56   Bangalore        Kolkata Knight Riders
# 57   Bangalore               Mumbai Indians
# 58   Hyderabad               Mumbai Indians
# 59   Bangalore        Kolkata Knight Riders
# 60  Chandigarh          Chennai Super Kings

# %% [markdown]
# 1.	Minimum Value: What is the minimum value in the 'win_by_runs' column?

# %%
min_in_column=df['win_by_runs'].min()
min_in_column
# Out:
# np.int64(0)

# %% [markdown]
# 2.	Maximum Value: What is the maximum value in the 'win_by_wickets' column?

# %%
max_in_column=df['win_by_wickets'].max()
max_in_column
# Out:
# np.int64(10)

# %% [markdown]
# 3.	Count of Non-Null Values: How many non-null values are there in the 'city' column?

# %%
y=df['city'].count()
y
# Out:
# np.int64(629)

# %%
#nonempty_in_column=df['city'].isna().value_counts()    #counts null and non null
#nonempty_in_column                                 
#df['city].isnull().sum()               counts empty values
# Out:
# city
# False    629
# True       7
# Name: count, dtype: int64

# %%
#nonempty_in_column=df['city'].isnull().value_counts(True)   #tells proportion
#nonempty_in_column

#city
#False    0.988994
#True     0.011006
#Name: proportion, dtype: float64

# %% [markdown]
# 4.	Count of Unique Values: How many unique teams are there in the 'team1' column?

# %%
unique_in_col=df['team1'].nunique()   #nuique() gives no. of unique values
unique_in_col                         #while unique() gives list of all unique values
# Out:
# 14

# %% [markdown]
# 5.	Sum of a Column: Calculate the total runs scored by all teams in the 'win_by_runs' column.

# %%
sum_column_values=df['win_by_runs'].sum()
sum_column_values
# Out:
# np.int64(8702)

# %% [markdown]
# 6.	Mean of a Column: What is the mean value of the 'win_by_runs' column?

# %%
mean_column=df['win_by_runs'].mean()               #.__round__()
mean_column
# Out:
# 14

# %% [markdown]
# 7.	Standard Deviation: Calculate the standard deviation of the 'win_by_runs' column.

# %%
st_deviation_column=df['win_by_runs'].std().__round__(1)
st_deviation_column
# Out:
# np.float64(23.9)

# %% [markdown]
# 8.	Count of Occurrences: How many times does the team 'Mumbai Indians' appear in the 'team1' column?

# %%
count_occurences=(df['team1']=='Mumbai Indians').sum()
count_occurences
# Out:
# np.int64(82)

# %% [markdown]
# 1.	Fetch Matches for 'Mumbai Indians': How would you fetch the matches where 'Mumbai Indians' played as 'team1'?

# %%
Mumbai_indians=df[df['team1']=='Mumbai Indians']
Mumbai_indians
# Out:
#       id  season           city        date           team1  \
# 1      2    2017           Pune  2017-04-06  Mumbai Indians
# 23    24    2017         Mumbai  2017-04-22  Mumbai Indians
# 43    44    2017          Delhi  2017-05-06  Mumbai Indians
# 46    47    2017      Hyderabad  2017-05-08  Mumbai Indians
# 52    53    2017        Kolkata  2017-05-13  Mumbai Indians
# ..   ...     ...            ...         ...             ...
# 587  588    2016      Hyderabad  2016-04-18  Mumbai Indians
# 596  597    2016     Chandigarh  2016-04-25  Mumbai Indians
# 618  619    2016  Visakhapatnam  2016-05-13  Mumbai Indians
# 622  623    2016  Visakhapatnam  2016-05-15  Mumbai Indians
# 629  630    2016         Kanpur  2016-05-21  Mumbai Indians
#
#                       team2             toss_winner toss_decision  result  \
# 1    Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 23         Delhi Daredevils        Delhi Daredevils         field  normal
# ...

# %% [markdown]
# 2.	Minimum Win by Runs: What is the smallest margin of victory (in runs) for a match in the dataset?

# %%
min_win_runs=min(df['win_by_runs'])
min_win_runs
# Out:
# 0

# %%
min_win_runs_matches=df[df['win_by_runs']==(min(df['win_by_runs']))]
min_win_runs_matches
# Out:
#       id  season           city        date                   team1  \
# 1      2    2017           Pune  2017-04-06          Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07           Gujarat Lions
# 3      4    2017         Indore  2017-04-08  Rising Pune Supergiant
# 5      6    2017      Hyderabad  2017-04-09           Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09   Kolkata Knight Riders
# ..   ...     ...            ...         ...                     ...
# 628  629    2016  Visakhapatnam  2016-05-21         Kings XI Punjab
# 629  630    2016         Kanpur  2016-05-21          Mumbai Indians
# 631  632    2016         Raipur  2016-05-22        Delhi Daredevils
# 632  633    2016      Bangalore  2016-05-24           Gujarat Lions
# 634  635    2016          Delhi  2016-05-27           Gujarat Lions
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# 3.	Maximum Win by Wickets: What is the highest number of wickets by which a team won a match?

# %%
max_win_wick=max(df['win_by_wickets'])
max_win_wick
# Out:
# 10

# %% [markdown]
# 4.	Count of Non-Null Values in 'City': How many matches have a non-null 'city' value?

# %%
city_notnull=df['city'].count()
city_notnull
# Out:
# np.int64(629)

# %% [markdown]
# 5.	Count Unique Teams in 'team1': How many different teams are there in the 'team1' column?

# %%
unique_team1=df['team1'].nunique()
unique_team1
# Out:
# 14

# %% [markdown]
# 6.	Total Runs Scored: What is the total number of runs scored in all matches combined?

# %%
total_runs=df['win_by_runs'].sum()
total_runs
# Out:
# np.int64(8702)

# %% [markdown]
# 7.	Mean Win by Runs: What is the average margin of victory (in runs) for all matches?

# %%
mean_win_runs=df['win_by_runs'].mean().__round__(1)
mean_win_runs
# Out:
# np.float64(13.7)

# %% [markdown]
# 1.	Sort by a Single Column: How would you sort the DataFrame based on the 'win_by_runs' column in ascending order?

# %%
sort_asc=df.sort_values(by='win_by_runs',ascending=True)
sort_asc
# Out:
#       id  season       city        date                        team1  \
# 629  630    2016     Kanpur  2016-05-21               Mumbai Indians
# 609  610    2016  Hyderabad  2016-05-06                Gujarat Lions
# 610  611    2016  Bangalore  2016-05-07      Rising Pune Supergiants
# 38    39    2017      Delhi  2017-05-02          Sunrisers Hyderabad
# 39    40    2017    Kolkata  2017-05-03        Kolkata Knight Riders
# ..   ...     ...        ...         ...                          ...
# 410  411    2013  Bangalore  2013-04-23  Royal Challengers Bangalore
# 556  557    2015  Bangalore  2015-05-06  Royal Challengers Bangalore
# 59    60    2008  Bangalore  2008-04-18        Kolkata Knight Riders
# 619  620    2016  Bangalore  2016-05-14  Royal Challengers Bangalore
# 43    44    2017      Delhi  2017-05-06               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# 2.	Sort by Multiple Columns: Can you sort the DataFrame based on 'season' in ascending order and then 'win_by_runs' in descending order?

# %%
sort_asc_desc=df.sort_values(by=['season', 'win_by_runs'], ascending=[True, False])
sort_asc_desc
# Out:
#       id  season        city        date                  team1  \
# 59    60    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 114  115    2008      Mumbai  2008-05-30       Rajasthan Royals
# 68    69    2008  Chandigarh  2008-04-25        Kings XI Punjab
# 100  101    2008      Jaipur  2008-05-17       Rajasthan Royals
# 77    78    2008      Jaipur  2008-05-01       Rajasthan Royals
# ..   ...     ...         ...         ...                    ...
# 48    49    2017      Kanpur  2017-05-10          Gujarat Lions
# 51    52    2017      Kanpur  2017-05-13          Gujarat Lions
# 53    54    2017        Pune  2017-05-14        Kings XI Punjab
# 56    57    2017   Bangalore  2017-05-17    Sunrisers Hyderabad
# 57    58    2017   Bangalore  2017-05-19  Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# 59   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %% [markdown]
# 3.	Sort and Display Top N Rows: Sort the DataFrame by 'win_by_runs' in descending order and display the top 5 matches.

# %%
sort_desc_rows=df.sort_values(by='win_by_runs',ascending=False)
sort_desc_rows.head()
# Out:
#       id  season        city        date                  team1  \
# 59    60    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 114  115    2008      Mumbai  2008-05-30       Rajasthan Royals
# 68    69    2008  Chandigarh  2008-04-25        Kings XI Punjab
# 100  101    2008      Jaipur  2008-05-17       Rajasthan Royals
# 77    78    2008      Jaipur  2008-05-01       Rajasthan Royals
#
#                            team2                  toss_winner toss_decision  \
# 59   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 114             Delhi Daredevils             Delhi Daredevils         field
# 68                Mumbai Indians               Mumbai Indians         field
# 100  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 77         Kolkata Knight Riders             Rajasthan Royals           bat
#
#      result  dl_applied                 winner  win_by_runs  win_by_wickets  \
# ...

# %% [markdown]
# 4.	Sort and Display Bottom N Rows: Sort the DataFrame by 'win_by_runs' in ascending order and display the bottom 10 matches.

# %%
win_runs_sort=df.sort_values(by='win_by_runs')
win_runs_sort.tail(10)
# Out:
#       id  season        city        date                        team1  \
# 8      9    2017        Pune  2017-04-11             Delhi Daredevils
# 541  542    2015     Chennai  2015-04-25          Chennai Super Kings
# 182  183    2010       Delhi  2010-03-17               Mumbai Indians
# 114  115    2008      Mumbai  2008-05-30             Rajasthan Royals
# 295  296    2011  Dharamsala  2011-05-17              Kings XI Punjab
# 410  411    2013   Bangalore  2013-04-23  Royal Challengers Bangalore
# 556  557    2015   Bangalore  2015-05-06  Royal Challengers Bangalore
# 59    60    2008   Bangalore  2008-04-18        Kolkata Knight Riders
# 619  620    2016   Bangalore  2016-05-14  Royal Challengers Bangalore
# 43    44    2017       Delhi  2017-05-06               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 8         Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %% [markdown]
# 1.	Drop Duplicates Based on a Single Column: How would you drop duplicate rows based on the 'team1' column?

# %%
duplic=df.drop_duplicates(subset=['team1'])
duplic
# Out:
#       id  season        city        date                        team1  \
# 0      1    2017   Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017        Pune  2017-04-06               Mumbai Indians
# 2      3    2017      Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017      Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017   Bangalore  2017-04-08  Royal Challengers Bangalore
# 6      7    2017      Mumbai  2017-04-09        Kolkata Knight Riders
# 8      9    2017        Pune  2017-04-11             Delhi Daredevils
# 10    11    2017     Kolkata  2017-04-13              Kings XI Punjab
# 60    61    2008  Chandigarh  2008-04-19          Chennai Super Kings
# 61    62    2008       Delhi  2008-04-19             Rajasthan Royals
# 63    64    2008     Kolkata  2008-04-20              Deccan Chargers
# 236  237    2011       Kochi  2011-04-09         Kochi Tuskers Kerala
# ...

# %% [markdown]
# 2.	Drop Duplicates Based on Multiple Columns: Can you drop duplicate rows based on both 'team1' and 'team2' columns?

# %%
duplicates=df.drop_duplicates(subset=['team1','team2'])
duplicates
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...            ...         ...                          ...
# 604  605    2016           Pune  2016-05-01      Rising Pune Supergiants
# 608  609    2016          Delhi  2016-05-05             Delhi Daredevils
# 610  611    2016      Bangalore  2016-05-07      Rising Pune Supergiants
# 628  629    2016  Visakhapatnam  2016-05-21              Kings XI Punjab
# 632  633    2016      Bangalore  2016-05-24                Gujarat Lions
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# 3.	Drop Duplicates and Keep First Occurrence: Drop duplicate rows based on 'city' and keep the first occurrence for each unique city.

# %%
city_dupl=df.drop_duplicates(subset=['city'],keep='first')        #keep=first is default even if we dont write
city_dupl
# Out:
#       id  season            city        date                        team1  \
# 0      1    2017       Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017            Pune  2017-04-06               Mumbai Indians
# 2      3    2017          Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017          Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017       Bangalore  2017-04-08  Royal Challengers Bangalore
# 6      7    2017          Mumbai  2017-04-09        Kolkata Knight Riders
# 10    11    2017         Kolkata  2017-04-13              Kings XI Punjab
# 14    15    2017           Delhi  2017-04-15             Delhi Daredevils
# 31    32    2017      Chandigarh  2017-04-28          Sunrisers Hyderabad
# 48    49    2017          Kanpur  2017-05-10                Gujarat Lions
# 64    65    2008          Jaipur  2008-04-21              Kings XI Punjab
# 66    67    2008         Chennai  2008-04-23          Chennai Super Kings
# ...

# %% [markdown]
# 4.	Drop Duplicates and Keep Last Occurrence: Drop duplicate rows based on 'city' and keep the last occurrence for each unique city

# %%
city_duplic=df.drop_duplicates(subset=['city'],keep='last')
city_duplic
# Out:
#       id  season            city        date                        team1  \
# 129  130    2009       Cape Town  2009-04-26              Kings XI Punjab
# 149  150    2009     East London  2009-05-08               Mumbai Indians
# 154  155    2009       Kimberley  2009-05-11              Deccan Chargers
# 161  162    2009  Port Elizabeth  2009-05-16               Mumbai Indians
# 164  165    2009    Bloemfontein  2009-05-17             Delhi Daredevils
# 168  169    2009          Durban  2009-05-20          Chennai Super Kings
# 171  172    2009       Centurion  2009-05-22             Delhi Daredevils
# 173  174    2009    Johannesburg  2009-05-24              Deccan Chargers
# 219  220    2010          Nagpur  2010-04-12              Deccan Chargers
# 277  278    2011           Kochi  2011-05-05         Kochi Tuskers Kerala
# 293  294    2011          Indore  2011-05-15             Rajasthan Royals
# 441  442    2013          Jaipur  2013-05-12          Chennai Super Kings
# ...

# %% [markdown]
# Total Matches per Season: How many matches were played in each season?

# %%
matches_per_season=df.groupby('season').size()
matches_per_season
# Out:
# season
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# 2017    59
# dtype: int64

# %% [markdown]
# Total Matches in Each City: How many matches were played in each city?

# %%
matches_per_city=df.groupby('city').size()
matches_per_city
# Out:
# city
# Abu Dhabi          7
# Ahmedabad         12
# Bangalore         66
# Bloemfontein       2
# Cape Town          7
# Centurion         12
# Chandigarh        46
# Chennai           48
# Cuttack            7
# Delhi             60
# Dharamsala         9
# Durban            15
# East London        3
# Hyderabad         49
# Indore             5
# Jaipur            33
# Johannesburg       8
# Kanpur             4
# Kimberley          3
# Kochi              5
# Kolkata           61
# Mumbai            85
# Nagpur             3
# Port Elizabeth     7
# Pune              32
# Raipur             6
# Rajkot            10
# Ranchi             7
# Sharjah            6
# Visakhapatnam     11
# dtype: int64

# %% [markdown]
# 3.	Total Wins per Team: What is the total number of wins for each team?

# %%
total_teams=df.groupby('winner').size()
total_teams
# Out:
# winner
# Chennai Super Kings            79
# Deccan Chargers                29
# Delhi Daredevils               62
# Gujarat Lions                  13
# Kings XI Punjab                70
# Kochi Tuskers Kerala            6
# Kolkata Knight Riders          77
# Mumbai Indians                 92
# Pune Warriors                  12
# Rajasthan Royals               63
# Rising Pune Supergiant         10
# Rising Pune Supergiants         5
# Royal Challengers Bangalore    73
# Sunrisers Hyderabad            42
# dtype: int64

# %%
#total_teams=df[['team1','team2']].nunique()
#total_teams


#team1    14
#team2    14
#dtype: int64
# Out:
# team1    14
# team2    14
# dtype: int64

# %% [markdown]
# 4.	Total Wins in Each Season: How many wins did each team secure in each season?

# %%
wins_per_season_per_team=df.groupby(['winner','season']).size()
wins_per_season_per_team
# Out:
# winner               season
# Chennai Super Kings  2008       9
#                      2009       8
#                      2010       9
#                      2011      11
#                      2012      10
#                                ..
# Sunrisers Hyderabad  2013      10
#                      2014       6
#                      2015       7
#                      2016      11
#                      2017       8
# Length: 84, dtype: int64

# %% [markdown]
# 5.	Maximum Win by Runs per Season: What is the maximum margin of victory (in runs) in a match for each season?

# %%
max_wins_per_season_per_team=df.groupby(['winner','season']).max()
max_wins_per_season_per_team
# Out:
#                              id            city        date  \
# winner              season
# Chennai Super Kings 2008    116          Mumbai  2008-05-31
#                     2009    169  Port Elizabeth  2009-05-20
#                     2010    234          Mumbai  2010-04-25
#                     2011    307          Mumbai  2011-05-28
#                     2012    380   Visakhapatnam  2012-05-25
# ...                         ...             ...         ...
# Sunrisers Hyderabad 2013    453            Pune  2013-05-19
#                     2014    507          Ranchi  2014-05-22
#                     2015    564   Visakhapatnam  2015-05-11
#                     2016    636   Visakhapatnam  2016-05-29
#                     2017     52          Kanpur  2017-05-13
#
#                                                   team1  \
# winner              season
# Chennai Super Kings 2008          Kolkata Knight Riders
#                     2009               Rajasthan Royals
# ...

# %%
max_win_by_runs = df.groupby('season')['win_by_runs'].max().reset_index()
print(max_win_by_runs)
# Out:
#    season  win_by_runs
# 0    2008          140
# 1    2009           92
# 2    2010           98
# 3    2011          111
# 4    2012           86
# 5    2013          130
# 6    2014           93
# 7    2015          138
# 8    2016          144
# 9    2017          146

# %% [markdown]
# 1.	Filter Matches by Specific Teams: How would you filter the matches where either 'Mumbai Indians' or 'Chennai Super Kings' played as either 'team1' or 'team2'?

# %%
#filter_match=df[(df['team1']['Mumbai Indians','Chennai Super Kings']) | (df['team2']['Mumbai Indians','Chennai Super Kings'])]
#filter_match   #wrong

# %%
filtered_matches = df[ (df['team1'].isin(['Mumbai Indians','Chennai Super Kings'])) | (df['team2'].isin(['Mumbai Indians','Chennai Super Kings'] ))  ]
filtered_matches
# Out:
#       id  season           city        date                        team1  \
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# 15    16    2017         Mumbai  2017-04-16                Gujarat Lions
# ..   ...     ...            ...         ...                          ...
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 616  617    2016      Bangalore  2016-05-11  Royal Challengers Bangalore
# 618  619    2016  Visakhapatnam  2016-05-13               Mumbai Indians
# 622  623    2016  Visakhapatnam  2016-05-15               Mumbai Indians
# 629  630    2016         Kanpur  2016-05-21               Mumbai Indians
#
#                       team2             toss_winner toss_decision  result  \
# ...

# %% [markdown]
# 2.  Filter Matches in Specific Cities: Can you filter the matches that took place in either 'Bangalore' or 'Delhi'?

# %%
filtered_matches_cities = df[ (df['city'].isin(['Bangalore','Delhi'])) ]
filtered_matches_cities
# Out:
#       id  season       city        date                        team1  \
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 11    12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 14    15    2017      Delhi  2017-04-15             Delhi Daredevils
# 16    17    2017  Bangalore  2017-04-16       Rising Pune Supergiant
# 17    18    2017      Delhi  2017-04-17             Delhi Daredevils
# ..   ...     ...        ...         ...                          ...
# 625  626    2016  Bangalore  2016-05-18  Royal Challengers Bangalore
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# 3.	Find Matches with Specific Umpires: How would you find the matches where either 'S Ravi' or 'HDPK Dharmasena' were either 'umpire1' or 'umpire2'?

# %%
filter_match_umpire = df[ (df['umpire1'].isin(['S Ravi','HDPK Dharmasena' ])) | (df['umpire2'].isin(['S Ravi','HDPK Dharmasena' ] ))  ]
filter_match_umpire
# Out:
#       id  season           city        date                        team1  \
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 12    13    2017         Rajkot  2017-04-14       Rising Pune Supergiant
# 15    16    2017         Mumbai  2017-04-16                Gujarat Lions
# 19    20    2017         Rajkot  2017-04-18  Royal Challengers Bangalore
# ..   ...     ...            ...         ...                          ...
# 614  615    2016     Chandigarh  2016-05-09  Royal Challengers Bangalore
# 618  619    2016  Visakhapatnam  2016-05-13               Mumbai Indians
# 628  629    2016  Visakhapatnam  2016-05-21              Kings XI Punjab
# 632  633    2016      Bangalore  2016-05-24                Gujarat Lions
# 635  636    2016      Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...
